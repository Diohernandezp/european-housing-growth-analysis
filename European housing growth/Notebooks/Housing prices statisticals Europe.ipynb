# %%
#instalamos las librerias necesarias para el proyecto
# !pip install matplotlib
# !pip install pandas
# !pip install seaborn
# !pip install numpy
print('Instaladas todas las librerias')
# Out:
# Requirement already satisfied: matplotlib in c:\users\dionn\anaconda3\lib\site-packages (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\dionn\anaconda3\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\dionn\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\dionn\anaconda3\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\dionn\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.23 in c:\users\dionn\anaconda3\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\dionn\anaconda3\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\dionn\anaconda3\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\dionn\anaconda3\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\dionn\anaconda3\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\dionn\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: pandas in c:\users\dionn\anaconda3\lib\site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\dionn\anaconda3\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\dionn\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dionn\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\dionn\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\dionn\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: seaborn in c:\users\dionn\anaconda3\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\dionn\anaconda3\lib\site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in c:\users\dionn\anaconda3\lib\site-packages (from seaborn) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\dionn\anaconda3\lib\site-packages (from seaborn) (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\dionn\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\dionn\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\dionn\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\dionn\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\dionn\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\dionn\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\dionn\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\dionn\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dionn\anaconda3\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\dionn\anaconda3\lib\site-packages (from pandas>=1.2->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\dionn\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Requirement already satisfied: numpy in c:\users\dionn\anaconda3\lib\site-packages (1.26.4)
# Instaladas todas las librerias

# %%
# !pip install geopandas
print('Instalada')
# Out:
# Requirement already satisfied: geopandas in c:\users\dionn\anaconda3\lib\site-packages (1.1.0)
# Requirement already satisfied: numpy>=1.24 in c:\users\dionn\anaconda3\lib\site-packages (from geopandas) (1.26.4)
# Requirement already satisfied: pyogrio>=0.7.2 in c:\users\dionn\anaconda3\lib\site-packages (from geopandas) (0.11.0)
# Requirement already satisfied: packaging in c:\users\dionn\anaconda3\lib\site-packages (from geopandas) (24.1)
# Requirement already satisfied: pandas>=2.0.0 in c:\users\dionn\anaconda3\lib\site-packages (from geopandas) (2.2.2)
# Requirement already satisfied: pyproj>=3.5.0 in c:\users\dionn\anaconda3\lib\site-packages (from geopandas) (3.7.1)
# Requirement already satisfied: shapely>=2.0.0 in c:\users\dionn\anaconda3\lib\site-packages (from geopandas) (2.1.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\dionn\anaconda3\lib\site-packages (from pandas>=2.0.0->geopandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dionn\anaconda3\lib\site-packages (from pandas>=2.0.0->geopandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\dionn\anaconda3\lib\site-packages (from pandas>=2.0.0->geopandas) (2023.3)
# Requirement already satisfied: certifi in c:\users\dionn\anaconda3\lib\site-packages (from pyogrio>=0.7.2->geopandas) (2024.8.30)
# Requirement already satisfied: six>=1.5 in c:\users\dionn\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->geopandas) (1.16.0)
# Instalada

# %%
#importo todas las librerias para comenzar a trabajar
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#cargo el data set
df = pd.read_csv('Housing prices statisticals.tsv', sep='\t')
print(df.head())
# Out:
#   freq,indic,unit,geo\TIME_PERIOD 2005-Q1  2005-Q2  2005-Q3  2005-Q4   \
# 0              Q,TOTAL,I15_NSA,AT       :        :        :        :
# 1              Q,TOTAL,I15_NSA,BE   70.03    71.59    74.12    75.65
# 2              Q,TOTAL,I15_NSA,BG  76.01 e  79.26 e  81.55 e  83.52 e
# 3              Q,TOTAL,I15_NSA,CY   93.41    95.38    98.79   100.64
# 4              Q,TOTAL,I15_NSA,CZ       :        :        :        :
#
#   2006-Q1  2006-Q2  2006-Q3  2006-Q4   2007-Q1   ... 2022-Q3  2022-Q4   \
# 0       :        :        :        :         :   ...  173.59   166.32
# 1   77.10    79.18    81.54    82.16     84.05   ...  134.96   134.55
# 2  87.47 e  88.91 e  92.96 e  98.09 e  107.23 e  ...  174.43   175.14
# 3  103.04   106.44   110.64   114.16    116.41   ...  109.95   108.27
# 4       :        :        :        :         :   ...  219.40   214.50
#
#   2023-Q1  2023-Q2  2023-Q3  2023-Q4  2024-Q1  2024-Q2  2024-Q3   2024-Q4
# 0  164.35   164.68   164.29   161.40   159.54   164.34   165.13   164.10 p
# 1  135.04   134.55   136.31   138.28   139.36   138.96   141.16   142.24 p
# 2  177.93   185.50   190.48   192.78   206.42   213.53   221.91   228.00 p
# 3  110.31   110.15   110.65   109.95   111.53   112.86   113.62    112.47
# 4  211.80   211.00   211.70   212.30   214.30   219.90   224.70    230.20
#
# [5 rows x 81 columns]

# %%
#obtengo un resumen consiso del data frame
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104 entries, 0 to 103
# Data columns (total 81 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   freq,indic,unit,geo\TIME_PERIOD  104 non-null    object
#  1   2005-Q1                          104 non-null    object
#  2   2005-Q2                          104 non-null    object
#  3   2005-Q3                          104 non-null    object
#  4   2005-Q4                          104 non-null    object
#  5   2006-Q1                          104 non-null    object
#  6   2006-Q2                          104 non-null    object
#  7   2006-Q3                          104 non-null    object
#  8   2006-Q4                          104 non-null    object
#  9   2007-Q1                          104 non-null    object
#  10  2007-Q2                          104 non-null    object
#  11  2007-Q3                          104 non-null    object
#  12  2007-Q4                          104 non-null    object
#  13  2008-Q1                          104 non-null    object
#  14  2008-Q2                          104 non-null    object
#  15  2008-Q3                          104 non-null    object
#  16  2008-Q4                          104 non-null    object
#  17  2009-Q1                          104 non-null    object
#  18  2009-Q2                          104 non-null    object
#  19  2009-Q3                          104 non-null    object
#  20  2009-Q4                          104 non-null    object
#  21  2010-Q1                          104 non-null    object
#  22  2010-Q2                          104 non-null    object
#  23  2010-Q3                          104 non-null    object
#  24  2010-Q4                          104 non-null    object
#  25  2011-Q1                          104 non-null    object
#  26  2011-Q2                          104 non-null    object
#  27  2011-Q3                          104 non-null    object
#  28  2011-Q4                          104 non-null    object
#  29  2012-Q1                          104 non-null    object
#  30  2012-Q2                          104 non-null    object
#  31  2012-Q3                          104 non-null    object
#  32  2012-Q4                          104 non-null    object
#  33  2013-Q1                          104 non-null    object
#  34  2013-Q2                          104 non-null    object
#  35  2013-Q3                          104 non-null    object
#  36  2013-Q4                          104 non-null    object
#  37  2014-Q1                          104 non-null    object
#  38  2014-Q2                          104 non-null    object
#  39  2014-Q3                          104 non-null    object
#  40  2014-Q4                          104 non-null    object
#  41  2015-Q1                          104 non-null    object
#  42  2015-Q2                          104 non-null    object
#  43  2015-Q3                          104 non-null    object
#  44  2015-Q4                          104 non-null    object
#  45  2016-Q1                          104 non-null    object
#  46  2016-Q2                          104 non-null    object
#  47  2016-Q3                          104 non-null    object
#  48  2016-Q4                          104 non-null    object
#  49  2017-Q1                          104 non-null    object
#  50  2017-Q2                          104 non-null    object
#  51  2017-Q3                          104 non-null    object
#  52  2017-Q4                          104 non-null    object
#  53  2018-Q1                          104 non-null    object
#  54  2018-Q2                          104 non-null    object
#  55  2018-Q3                          104 non-null    object
#  56  2018-Q4                          104 non-null    object
#  57  2019-Q1                          104 non-null    object
#  58  2019-Q2                          104 non-null    object
#  59  2019-Q3                          104 non-null    object
#  60  2019-Q4                          104 non-null    object
#  61  2020-Q1                          104 non-null    object
#  62  2020-Q2                          104 non-null    object
#  63  2020-Q3                          104 non-null    object
#  64  2020-Q4                          104 non-null    object
#  65  2021-Q1                          104 non-null    object
#  66  2021-Q2                          104 non-null    object
#  67  2021-Q3                          104 non-null    object
#  68  2021-Q4                          104 non-null    object
#  69  2022-Q1                          104 non-null    object
#  70  2022-Q2                          104 non-null    object
#  71  2022-Q3                          104 non-null    object
#  72  2022-Q4                          104 non-null    object
#  73  2023-Q1                          104 non-null    object
#  74  2023-Q2                          104 non-null    object
#  75  2023-Q3                          104 non-null    object
#  76  2023-Q4                          104 non-null    object
#  77  2024-Q1                          104 non-null    object
#  78  2024-Q2                          104 non-null    object
#  79  2024-Q3                          104 non-null    object
#  80  2024-Q4                          104 non-null    object
# dtypes: object(81)
# memory usage: 65.9+ KB
# None

# %%
#obtengo el tipo de datos que contiene el data frame
print(df.dtypes)
# Out:
# freq,indic,unit,geo\TIME_PERIOD    object
# 2005-Q1                            object
# 2005-Q2                            object
# 2005-Q3                            object
# 2005-Q4                            object
#                                     ...
# 2023-Q4                            object
# 2024-Q1                            object
# 2024-Q2                            object
# 2024-Q3                            object
# 2024-Q4                            object
# Length: 81, dtype: object

# %%
#obtengo una descripcion de todo lo que contiene el data frame
print(df.describe())
# Out:
#        freq,indic,unit,geo\TIME_PERIOD 2005-Q1  2005-Q2  2005-Q3  2005-Q4   \
# count                              104      104      104      104      104
# unique                             104       20       35       36       38
# top                 Q,TOTAL,I15_NSA,AT       :        :        :        :
# freq                                 1       85       66       66       65
#
#        2006-Q1  2006-Q2  2006-Q3  2006-Q4  2007-Q1   ... 2022-Q3  2022-Q4   \
# count       104      104      104      104      104  ...      104      104
# unique       60       63       63       63       71  ...       84       84
# top          :        :        :        :        :   ...     0.8     -1.5
# freq         42       39       39       38       32  ...        4        4
#
#        2023-Q1  2023-Q2  2023-Q3  2023-Q4  2024-Q1  2024-Q2  2024-Q3  2024-Q4
# count       104      104      104      104      104      104      104      104
# unique       89       90       88       88       90       85       83       93
# top       -0.7      1.9        :     -1.0      0.6      3.0      1.5      2.4
# freq          3        3        3        3        3        5        4        4
#
# [4 rows x 81 columns]

# %%
#Dado que los nombres de las columnas son abreviados los renombro
df[['Frecuency', 'Indicator','Unit','Geo']] = df[r'freq,indic,unit,geo\TIME_PERIOD'].str.split(',', expand = True)

# %%
#ahora procedo a eliminar la columna original
df.drop(columns = [r'freq,indic,unit,geo\TIME_PERIOD'], inplace = True)

# %%
#reorganizo el data set para el analisis temporal
df_melted = df.melt(id_vars=['Geo'], var_name = 'Time', value_name = 'Price')

# %%
#limpio la columna 'Tiempo' para poder utilizarla
df_melted['Time'] = df_melted['Time'].str.extract(r'(\d{4}-Q\d)')
df_melted.dropna(subset=['Time'], inplace = True)
df_melted['Year'] = df_melted['Time'].str[:4].astype(int)

# %%
#Dado que los precios estan en tipo objeto los convierto a un formato numerico
df_melted['Price'] = pd.to_numeric(df_melted['Price'], errors = 'coerce')

# %%
#terminado todo este proceso, muestro los graficos por region
plt.figure(figsize=(14,7))
sns.lineplot(x='Year', y='Price', hue='Geo', data=df_melted)
plt.xlabel('Year')
plt.ylabel('Housing Prices')
plt.title('Prices Evolution by Region')
plt.legend(title='Region', bbox_to_anchor=(1.05,1), loc='upper left')
plt.tight_layout()
plt.savefig('Prices Evolution by Region.png')
plt.show()

# %%
#como el grafico resulta ser confuso por la cantidad de paises
#pasamos a estandarizar las unidades de medicion y tomar los datos de los
#paises mas representativos con I15_NSA

df_idx = df[df['Unit'] == 'I15_NSA']
df_melted = df_idx.melt(id_vars=['Geo'], var_name = 'Time', value_name = 'Index')
df_melted['Time'] = df_melted['Time'].str.extract(r'(\d{4}-Q\d)')
df_melted.dropna(inplace = True)
df_melted['Year'] = df_melted['Time'].str[:4].astype(int)
df_melted['Index'] = pd.to_numeric(df_melted['Index'], errors = 'coerce')

# %%
#tomo los paises mas representativos
top_geos = (
    df_melted.groupby('Geo')['Index']
    .mean()
    .sort_values(ascending=False)
    .head(11)
    .index
)
df_top = df_melted[df_melted['Geo'].isin(top_geos)]

# %%
#procedo nuevamente a graficar
sns.set(style = 'whitegrid')
plt.figure(figsize=(12,6))
sns.lineplot(data=df_top, x='Year', y='Index', hue="Geo", palette = 'tab10')

plt.title('Evolution of the House Price Index in Europe 11 main countries')
plt.xlabel('Year')
plt.ylabel('Index (Base 100)')
plt.legend(title='Country', loc = 'upper left')
plt.tight_layout()
plt.savefig('Evolution of the House Price Index in Europe 11 main countries')
plt.show()

# %%
#Para evitar confusiones por las siglas de los nombres de paises creo un diccionario
nombres_paises = {
    'AT':'Austria',
    'BE':'Bélgica',
    'CH':'Suiza',
    'DE':'Alemania',
    'DK':'Dinamarca',
    'ES':'España',
    'FI':'Finlandia',
    'FR':'Francia',
    'LU':'Luxemburgo',
    'NL':'Paises Bajos'
}

#Hago la lista de codigos a usar
paises_iso = list(nombres_paises.keys())

#Filtro y creo las etiquetas
df_top = df_melted[df_melted['Geo'].isin(paises_iso)].copy()
df_top['Geo_label'] = df_top['Geo'].map(lambda x:f'{x} - {nombres_paises[x]}')

# %%
#Ahora nuevamente grafico con las etiquetas legibles
sns.set(style='whitegrid')
plt.figure(figsize=(14,7))

sns.lineplot(
    data=df_top,
    x='Year',
    y='Index',
    hue='Geo_label',
    palette='tab10'
)
plt.title('Evolution of the Housing Price Index in Europe 11 main countries (2005-2024)')
plt.xlabel('Year')
plt.ylabel('Index (Base 100)')
plt.legend(title='Country', loc='upper left', bbox_to_anchor=(1.05,1))
plt.tight_layout()
plt.savefig('Evolution of the Housing Price Index in Europe 11 main countries (2005-2024).png')
plt.show()

# %%
#ahora agrupamos par calcular el crecimiento de los paises
df_clean = df_top.dropna(subset=['Index']).copy()
df_clean = df_clean.sort_values(['Geo_label','Year'])

df_summary = df_clean.groupby('Geo_label').agg(
    inicio=('Index', lambda x: x.iloc[0]),
    final=('Index', lambda x: x.iloc[-1])
).dropna()

df_summary['Crecimiento %'] = ((df_summary['final'] - df_summary['inicio']) / df_summary['inicio']) * 100
df_summary = df_summary.sort_values('Crecimiento %', ascending = False)

# %%
#Genero el grafico de barras para ver el crecimiento por pais
plt.figure(figsize=(12,6))
sns.barplot(
    data=df_summary.reset_index(),
    x='Geo_label',
    y='Crecimiento %',
    hue='Geo_label',
    palette = 'viridis',
    legend = False
)
plt.title("Cumulative Growth of the Housing Price Index in 11 Major Countries (2005–2024)")
plt.xlabel('Country')
plt.ylabel('Growth (%)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig("Cumulative Growth of the Housing Price Index in 11 Major Countries (2005–2024).png")
plt.show()

# %%
#para cerrar generamos un mapa de calor en referencia al crecimiento del precio
#de la vivienda por pais
#Importamos la libreria geopandas
import geopandas as gpd

#Cargo el archivo shapefile previamente descargado
ruta_mapa = r'C:\Users\dionn\Desktop\PYTHON\PROYECTOS\ne_110m_admin_0_countries\ne_110m_admin_0_countries.shp'
world = gpd.read_file(ruta_mapa)

#filtro Europa y paises relevantes
paises_objetivo = df_summary.reset_index()

#Extraigo los codigos ISO
paises_objetivo['iso_a2'] = paises_objetivo['Geo_label'].str[:2]

europe = world[world['CONTINENT'] == 'Europe']
europe = europe[europe['ISO_A2'].isin(paises_objetivo['iso_a2'])]

#Uno los datos del indice al mapa
europe = europe.merge(paises_objetivo, left_on='ISO_A2', right_on='iso_a2', how='left')

europe.plot(
    column = 'Crecimiento %',
    cmap='Greens',
    linewidth = 1.2,
    edgecolor = 'black',
    legend = True,
    legend_kwds = {'label':'Cumulative Growth (%)', 'orientation':'vertical'},
    figsize=(10,8)
)

# Identifico cada mapa con el nombre del pais que representa

for idx, row in europe.iterrows():
    if row["geometry"].centroid.is_empty:
        continue
    x, y = row["geometry"].centroid.coords[0]
    label = row["ISO_A2"]
    plt.text(
        x, y,
        label,
        fontsize=8,
        ha="center",
        va="center",
        color="black",
        weight="bold",
        alpha=0.85
    )

#Para evitar confusiones añado una nota a pie de grafico

plt.figtext(
    0.5, -0.05,
    "Note: The spatial arrangement of the map is a visual representation\n Size and proximity between countries do not imply shared borders.",
    ha='center',
    fontsize = 9,
    color = 'gray'
)

plt.title('Heat map of cumulative growth in housing prices in 11 major countries (2005–2024)')
plt.axis('off')
plt.tight_layout()
plt.savefig('Heat map of cumulative growth in housing prices in 11 major countries (2005–2024).png')
plt.show()
